# %%
import pymongo
from pymongo import MongoClient

# %%
connction_string="mongodb+srv://subodhkumary933_db_user:vEa7tLDChSnB8TTO@cluster0.sproagh.mongodb.net/?appName=Cluster0"

# %%
client=MongoClient(connction_string)

# %%
db=client["snsr"]

# %%
collection=db["mongo_"]

# %%
data={
    'name':'subodh kumar yadav ',
    'age':21,
    'email':'subodhkumary933@gmail.com'
}

# %%
collection.insert_one(data)
# Out:
# InsertOneResult(ObjectId('6971cfa1f9ecce272a269cc3'), acknowledged=True)

# %%
# now fetch the data into the mongo to the local

# %%
cursor=collection.find({})
for i in cursor:
    print(i)
# Out:
# {'_id': ObjectId('6971cfa1f9ecce272a269cc3'), 'name': 'subodh kumar yadav ', 'age': 21, 'email': 'subodhkumary933@gmail.com'}
