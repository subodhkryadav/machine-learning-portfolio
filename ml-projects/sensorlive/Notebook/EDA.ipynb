# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Load the data set

# %%
df=pd.read_csv("D:/sensorlive\Data_set/aps_failure_training_set.csv")

# %%
df
# Out:
#       class  aa_000  ab_000        ac_000  ad_000  ae_000  af_000  ag_000  \
# 0       pos  153204     0.0  1.820000e+02     NaN     0.0     0.0     0.0
# 1       pos  453236     NaN  2.926000e+03     NaN     0.0     0.0     0.0
# 2       pos   72504     NaN  1.594000e+03  1052.0     0.0     0.0     0.0
# 3       pos  762958     NaN           NaN     NaN     NaN     NaN   776.0
# 4       pos  695994     NaN           NaN     NaN     NaN     NaN     0.0
# ...     ...     ...     ...           ...     ...     ...     ...     ...
# 36183   neg  153002     NaN  6.640000e+02   186.0     0.0     0.0     0.0
# 36184   neg    2286     NaN  2.130707e+09   224.0     0.0     0.0     0.0
# 36185   neg     112     0.0  2.130706e+09    18.0     0.0     0.0     0.0
# 36186   neg   80292     NaN  2.130706e+09   494.0     0.0     0.0     0.0
# 36187   neg   40222     NaN  6.980000e+02   628.0     0.0     0.0     0.0
#
#          ag_001     ag_002  ...     ee_002     ee_003     ee_004     ee_005  \
# ...

# %%
# know the shape of the dataset
df.shape
# Out:
# (36188, 171)

# %%
df.isnull().sum()
# Out:
# class         0
# aa_000        0
# ab_000    27896
# ac_000     2141
# ad_000     9200
#           ...
# ee_007      379
# ee_008      379
# ee_009      379
# ef_000     1730
# eg_000     1729
# Length: 171, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## check the data type
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
## checkk the unique values of the target variable
df["class"].value_counts()
# Out:
# class
# neg    35188
# pos     1000
# Name: count, dtype: int64

# %% [markdown]
# #### Above result show that the total target varible negative values and total positive values

# %% [markdown]
# ## Define the numerical column and categorical column

# %%
# define numerical & categorical columns
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# print columns
print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# We have 170 numerical features : ['aa_000', 'ab_000', 'ac_000', 'ad_000', 'ae_000', 'af_000', 'ag_000', 'ag_001', 'ag_002', 'ag_003', 'ag_004', 'ag_005', 'ag_006', 'ag_007', 'ag_008', 'ag_009', 'ah_000', 'ai_000', 'aj_000', 'ak_000', 'al_000', 'am_0', 'an_000', 'ao_000', 'ap_000', 'aq_000', 'ar_000', 'as_000', 'at_000', 'au_000', 'av_000', 'ax_000', 'ay_000', 'ay_001', 'ay_002', 'ay_003', 'ay_004', 'ay_005', 'ay_006', 'ay_007', 'ay_008', 'ay_009', 'az_000', 'az_001', 'az_002', 'az_003', 'az_004', 'az_005', 'az_006', 'az_007', 'az_008', 'az_009', 'ba_000', 'ba_001', 'ba_002', 'ba_003', 'ba_004', 'ba_005', 'ba_006', 'ba_007', 'ba_008', 'ba_009', 'bb_000', 'bc_000', 'bd_000', 'be_000', 'bf_000', 'bg_000', 'bh_000', 'bi_000', 'bj_000', 'bk_000', 'bl_000', 'bm_000', 'bn_000', 'bo_000', 'bp_000', 'bq_000', 'br_000', 'bs_000', 'bt_000', 'bu_000', 'bv_000', 'bx_000', 'by_000', 'bz_000', 'ca_000', 'cb_000', 'cc_000', 'cd_000', 'ce_000', 'cf_000', 'cg_000', 'ch_000', 'ci_000', 'cj_000', 'ck_00
# ...

# %% [markdown]
# ### In this data set (sensor data) the interpretation of the data is not required

# %% [markdown]
# ### checking the missing values

# %%
# checking the missing values using the ploting
fig,ax=plt.subplots(figsize=(15,5))
missing=df.isna().sum().div(df.shape[0]).mul(100).to_frame().sort_values(by=0,ascending=False)
ax.bar(missing.index,missing.values.T[0])
plt.xticks([])
plt.ylabel("percentage missing")
plt.show()

# %% [markdown]
# ### Droping columns which has more than 70% of missing values

# %%
dropcols=missing[missing[0]>70]
dropcols
# Out:
#                 0
# br_000  81.410965
# bq_000  80.501824
# bp_000  78.794075
# cr_000  77.086327
# ab_000  77.086327
# bo_000  76.533658
# bn_000  72.761689

# %%
df.drop(list(dropcols.index),axis=1,inplace=True)

# %%
# check the shape of the dataset after droping columns
df.shape
# Out:
# (36188, 164)

# %% [markdown]
# ### check the total percentage of missing values of full dataset after droping columns with more than 70% of missing values

# %%
missing_values_count=df.isnull().sum()
total_elements = np.prod(df.shape)
totall_missing=missing_values_count.sum()

# %%
print(f"Percantage of total missing cells in the data {(totall_missing/total_elements)*100}%")
# Out:
# Percantage of total missing cells in the data 5.37059852747306%

# %% [markdown]
# ## Visulization of unique values in Target variable

# %%
pos=df[df["class"]=='pos'].shape[0]
neg=df[df["class"]=='neg'].shape[0]
print("positive: "+str(pos)+",Negative: "+str(neg))
sns.catplot(data=df,x="class",kind="count",palette="winter_r",alpha=.6)
plt.show()
# Out:
# positive: 1000,Negative: 35188
# C:\Users\subod\AppData\Local\Temp\ipykernel_15608\3136139068.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=df,x="class",kind="count",palette="winter_r",alpha=.6)

# %% [markdown]
# # Report
#
# * The target classes are highly imbalanced
# * Class imbalance is a scenario that arises when we have unequal distribution of class in a dataset i.e. the no. of data points in the negative class (majority class) very large compared to that of the positive class (minority class)
# * If the imbalanced data is not treated beforehand, then this will degrade the performance of the classifier model.
# * Hence we should handle imbalanced data with certain methods.
#
# ### How to handle Imbalance Data ?
#
# * Resampling data is one of the most commonly preferred approaches to deal with an imbalanced dataset. There are broadly two types of methods for this i) Undersampling ii) Oversampling. In most cases, oversampling is preferred over undersampling techniques. The reason being, in undersampling we tend to remove instances from data that may be carrying some important information.
# * **SMOTE:** Synthetic Minority Oversampling Technique
# * SMOTE is an oversampling technique where the synthetic samples are generated for the minority class.
# * Hybridization techniques involve combining both undersampling and oversampling techniques. This is done to optimize the performance of classifier models for the samples created as part of these techniques.
# * It only duplicates the data and it won't add and new information. Hence we look at some different techniques.

# %% [markdown]
# ## saved the clean dataset

# %%
df.to_csv("cleaned_dataset.csv")
