# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/avnyadav/sensor-fault-detection/main/aps_failure_training_set1.csv"

# %%
df = pd.read_csv(url, na_values="na")

# %%
df.to_csv("aps_failure_training_set.csv", index=False)
